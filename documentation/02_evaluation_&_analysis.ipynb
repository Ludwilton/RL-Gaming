# %% [markdown]
# Focus: Results, metrics, generalization, discussion, limitations, future work, demo or screenshots.

# %% [markdown]
# Visa axplock av tränings levels och test levels

# %% [markdown]
# Plots. för den frdiga modellen använda en succses rate för hur många gånger den klara bana med en fix antal körningar av banan.
# Och plocka med data från hur träning har gott till

# %% [markdown]
# Demo, visar hur den navigerar test levels

# %% [markdown]
# Skriva till hur vi anpassat i våra slut resultat och scope efter våra begrännsningar privat och tidsmässigt.
